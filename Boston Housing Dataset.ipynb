# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

data = load_boston()
data.keys()
# feature selection and engineering is already mainly taken care of for us by authors of dataset
# https://scikit-learn.org/stable/datasets/index.html#boston-dataset
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
data["feature_names"]
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
X, y = data["data"], data["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train = pd.DataFrame(X_train,columns=data["feature_names"])
X_test = pd.DataFrame(X_test,columns=data["feature_names"])
y_train = pd.DataFrame(y_train,columns=["target"])
y_test = pd.DataFrame(y_test,columns=["target"])
X_train.info() # Don't have any null values but may want to think about null value strategy in case
                # we later encounter null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     404 non-null    float64
#  1   ZN       404 non-null    float64
#  2   INDUS    404 non-null    float64
#  3   CHAS     404 non-null    float64
#  4   NOX      404 non-null    float64
#  5   RM       404 non-null    float64
#  6   AGE      404 non-null    float64
#  7   DIS      404 non-null    float64
#  8   RAD      404 non-null    float64
#  9   TAX      404 non-null    float64
#  10  PTRATIO  404 non-null    float64
#  11  B        404 non-null    float64
#  12  LSTAT    404 non-null    float64
# dtypes: float64(13)
# memory usage: 41.2 KB

# %%
X_train.head()
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 0   0.35809   0.0   6.20   1.0  0.507  6.951  88.5  2.8617   8.0  307.0
# 1   0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873   4.0  305.0
# 2   0.11329  30.0   4.93   0.0  0.428  6.897  54.3  6.3361   6.0  300.0
# 3   0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605   5.0  311.0
# 4  25.94060   0.0  18.10   0.0  0.679  5.304  89.1  1.6475  24.0  666.0
#
#    PTRATIO       B  LSTAT
# 0     17.4  391.70   9.71
# 1     19.2  376.94   9.88
# 2     16.6  391.25  11.38
# 3     15.2  395.60  12.43
# 4     20.2  127.36  26.64

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)
X_train.hist(ax=ax)
plt.show()
# Out:
# /Users/maxschallwig/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X_train.describe()# looking at percentiles to get quick sense of distribution in smaller scales
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.386324   11.794554   11.123441    0.069307    0.555886    6.301797
# std      8.137943   23.636906    6.993011    0.254290    0.115201    0.694692
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.078935    0.000000    5.130000    0.000000    0.449000    5.887750
# 50%      0.256510    0.000000    9.125000    0.000000    0.538000    6.211000
# 75%      3.359358   20.000000   18.100000    0.000000    0.631000    6.675000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.027228    3.770242    9.403465  402.844059   18.462376  358.785446
# std     28.106955    2.080583    8.661147  170.857022    2.194821   88.663438
# min      2.900000    1.174200    1.000000  187.000000   12.600000    0.320000
# 25%     45.675000    2.087875    4.000000  276.000000   17.400000  376.132500
# 50%     77.950000    3.190950    5.000000  322.000000   19.100000  391.600000
# 75%     93.900000    5.141475   24.000000  666.000000   20.200000  396.060000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  404.000000
# mean    12.706188
# std      7.299031
# min      1.730000
# 25%      6.727500
# 50%     11.300000
# 75%     17.112500
# max     36.980000

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
pd.plotting.scatter_matrix(X_train,ax=ax,c=y_train["target"],alpha=0.5)
plt.show()
# visually we can see color separation across range of values
# Out:
# /Users/maxschallwig/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pd.concat([X_train,y_train],axis=1).corr()[["target"]] \
            .sort_values("target",ascending=False) \
            .style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
#     #T_a3c3aaac_9290_11ea_82cf_dca90474d457row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row1_col0 {
#             background-color:  #d4ea66;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row2_col0 {
#             background-color:  #a9d466;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row3_col0 {
#             background-color:  #a1d066;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row4_col0 {
#             background-color:  #97cb66;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row5_col0 {
#             background-color:  #88c366;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row6_col0 {
#             background-color:  #329866;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row7_col0 {
#             background-color:  #319866;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row8_col0 {
#             background-color:  #309866;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row9_col0 {
#             background-color:  #2b9566;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row10_col0 {
#             background-color:  #239166;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row11_col0 {
#             background-color:  #219066;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row12_col0 {
#             background-color:  #1c8e66;
#             color:  #000000;
#         }    #T_a3c3aaac_9290_11ea_82cf_dca90474d457row13_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_a3c3aaac_9290_11ea_82cf_dca90474d457" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >target</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row0" class="row_heading level0 row0" >target</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row0_col0" class="data row0 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row1" class="row_heading level0 row1" >RM</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row1_col0" class="data row1 col0" >0.705039</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row2" class="row_heading level0 row2" >ZN</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row2_col0" class="data row2 col0" >0.409824</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row3" class="row_heading level0 row3" >B</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row3_col0" class="data row3 col0" >0.354226</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row4" class="row_heading level0 row4" >DIS</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row4_col0" class="data row4 col0" >0.281013</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row5" class="row_heading level0 row5" >CHAS</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row5_col0" class="data row5 col0" >0.177620</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row6" class="row_heading level0 row6" >CRIM</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row6_col0" class="data row6 col0" >-0.411133</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row7" class="row_heading level0 row7" >AGE</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row7_col0" class="data row7 col0" >-0.413340</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row8" class="row_heading level0 row8" >RAD</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row8_col0" class="data row8 col0" >-0.425133</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row9" class="row_heading level0 row9" >NOX</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row9_col0" class="data row9 col0" >-0.459566</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row10" class="row_heading level0 row10" >TAX</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row10_col0" class="data row10 col0" >-0.511025</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row11" class="row_heading level0 row11" >INDUS</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row11_col0" class="data row11 col0" >-0.525054</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row12" class="row_heading level0 row12" >PTRATIO</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row12_col0" class="data row12 col0" >-0.563566</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c3aaac_9290_11ea_82cf_dca90474d457level0_row13" class="row_heading level0 row13" >LSTAT</th>
#                         <td id="T_a3c3aaac_9290_11ea_82cf_dca90474d457row13_col0" class="data row13 col0" >-0.755666</td>
#             </tr>
#     </tbody></table>

# %%
y_train.hist(bins=20)
# investigate train target distribution to see if we notice anything particular
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10e2bcd10>]],
#       dtype=object)
